# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
from pandas.plotting import scatter_matrix
import re
dataset = pd.read_csv('./Dataset DAMI.csv')

# %%
dataset.head()
# Out:
#    Shot Length  Motion Distribution Mean  Motion Distribution Variance  \
# 0     0.002895                  0.060724                      0.040575
# 1     0.002925                  0.044562                      0.014625
# 2     0.002482                  0.093887                      0.015300
# 3     0.001802                  0.147884                      0.021045
# 4     0.001507                  0.144648                      0.023990
#
#    Frame Difference Distribution Mean  Frame Difference Distribution Variance  \
# 0                            0.083315                                0.084338
# 1                            0.060140                                0.050334
# 2                            0.141953                                0.091546
# 3                            0.149998                                0.042480
# 4                            0.153792                                0.041816
#
#    Short time energy Mean  Short time energy Variance  ZCR Mean  ZCR Variance  \
# 0                0.358569                    0.500981  0.232525      0.206078
# 1                0.225931                    0.536515  0.191367      0.267263
# 2                0.411570                    0.667445  0.238775      0.182628
# 3                0.378323                    0.515456  0.233283      0.177615
# 4                0.566698                    0.563177  0.273774      0.213584
#
#    SpectralCentroid Mean  ...  Text Area Distribution bin_118  \
# 0               0.950609  ...                        0.517985
# 1               0.865285  ...                        0.425859
# 2               0.948145  ...                        0.382311
# 3               0.939038  ...                        0.340804
# 4               0.944723  ...                        0.328239
#
#    Text Area Distribution bin_119  Bag Audio Words bin_491  \
# 0                        0.382913                 0.080903
# 1                        0.112487                 0.087530
# 2                        0.084390                 0.080668
# 3                        0.008571                 0.157307
# 4                        0.000054                 0.024328
#
#    Bag Audio Words bin_572  Bag Audio Words bin_573  Bag Audio Words bin_623  \
# 0                 0.143516                 0.098794                 0.055650
# 1                 0.012675                 0.035933                 0.094324
# 2                 0.038831                 0.084629                 0.152727
# 3                 0.012413                 0.082227                 0.233325
# 4                 0.007048                 0.147480                 0.165863
#
#    Bag Audio Words bin_816  Edge Change Ratio Mean  \
# 0                 0.039385                0.422327
# 1                 0.025183                0.332652
# 2                 0.057944                0.346662
# 3                 0.084653                0.993349
# 4                 0.019128                0.341508
#
#    Edge Change Ratio Variance  Label
# 0                    0.663919      1
# 1                    0.766185      1
# 2                    0.225021      1
# 3                    0.840085      1
# 4                    0.710471      1
#
# [5 rows x 100 columns]

# %%
# Feature vector dan target variable
X = dataset.drop(['Label'], axis=1)

y = dataset['Label']

# %%
# Import fungsi train_test_split 
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3,random_state=1)

# %%
from sklearn.svm import SVC
clf = SVC(kernel='linear', C=1)
clf.fit(X_train, y_train)
# Out:
# SVC(C=1, kernel='linear')

# %%
from sklearn import metrics
y_pred = clf.predict(X_train)
print("Train Accuracy:",metrics.accuracy_score(y_train, y_pred))
# Out:
# Train Accuracy: 0.8586287674150125

# %%
from sklearn import metrics
y_pred = clf.predict(X_test)
print("Test Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Test Accuracy: 0.8549087295360636
