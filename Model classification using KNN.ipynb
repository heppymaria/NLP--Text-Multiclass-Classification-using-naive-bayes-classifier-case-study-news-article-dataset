# %% [markdown]
# # Data Understanding

# %%
import warnings; warnings.simplefilter("ignore")

# %%
import matplotlib.pyplot as plt
import pandas as pd
from pandas.plotting import scatter_matrix
import numpy as np
import seaborn as sns
import sklearn
# %matplotlib inline

# %% [markdown]
# **Load the data**

# %%
BBC = pd.read_excel('./Data/BBC_Cleaned.xlsx')
CNN = pd.read_excel('./Data/CNN_Cleaned.xlsx')
CNNIBN = pd.read_excel('./Data/CNNIBN_Cleaned.xlsx')
NDTV = pd.read_excel('./Data/NDTV_Cleaned.xlsx')
TIMESNOW = pd.read_excel('./Data/TIMESNOW_Cleaned.xlsx')

# %% [markdown]
# ## Exploratory Data Analysis

# %%
nRow, nCol = BBC.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 17720 rows and 205 columns

# %%
nRow, nCol = CNN.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 22545 rows and 201 columns

# %%
nRow, nCol = CNNIBN.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 33117 rows and 205 columns

# %%
nRow, nCol = NDTV.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 17051 rows and 205 columns

# %%
nRow, nCol = TIMESNOW.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 39252 rows and 204 columns

# %%
BBC.sample(5)
# Out:
#          1         2         3          4         5         6         7  \
# 15083   25  0.752715  0.372996   9.706425  6.479317  0.027234  0.013764
# 12420  122  0.285847  0.129955   2.292028  0.523953  0.017375  0.013822
# 15084   27  1.114959  0.674311  10.687413  9.282892  0.025282  0.013250
# 2781    25  0.062502  0.029880   0.605094  0.269641  0.016948  0.009075
# 15856   25  0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
#
#               8         9           10  ...  882       924       959  \
# 15083  0.035125  0.026806  3296.580811  ...  NaN       NaN       NaN
# 12420  0.113320  0.046764  3829.209229  ...  NaN  0.017094  0.012821
# 15084  0.042361  0.027864  3378.785156  ...  NaN       NaN       NaN
# 2781   0.102250  0.057741  3353.958008  ...  NaN       NaN       NaN
# 15856  0.000000  0.000000     0.000000  ...  NaN       NaN       NaN
#
#            1002      1016      1048  1112      4124      4125  Label
# ...

# %%
CNN.sample(5)
# Out:
#         1          2         3          4          5         6         7  \
# 1558  111   0.173451  0.158652   4.584739   4.035002  0.015304  0.009396
# 5438   44  13.035763  5.794026  37.141781  22.859711  0.014326  0.007102
# 1997  231   3.581510  3.480796   9.335437   5.727442  0.016959  0.011345
# 6329  352   0.950557  1.339799   8.630550  11.966099  0.019777  0.009329
# 5763   85   3.197760  2.121776  21.483160  26.725479  0.019544  0.006734
#
#              8         9           10  ...       924       959      1002  \
# 1558  0.214893  0.106327  3856.526123  ...       NaN  0.025943       NaN
# 5438  0.133594  0.061687  3638.307129  ...       NaN       NaN  0.064103
# 1997  0.101461  0.049196  3899.390625  ...  0.002212  0.014381  0.001106
# 6329  0.125746  0.054973  3947.312744  ...       NaN       NaN       NaN
# 5763  0.141949  0.063483  3802.584229  ...       NaN       NaN       NaN
#
#           1016  1028      1048  1112      4124      4125  Label
# ...

# %%
CNNIBN.sample(5)
# Out:
#          1         2         3          4          5         6         7  \
# 1514    40  3.494095  2.639509  10.043329   8.833490  0.021268  0.016554
# 9728   105  3.439684  2.128511   8.696930   4.151609  0.015989  0.006860
# 3857    47  1.763095  1.235244  10.673331   9.389985  0.015554  0.008748
# 26578   25  1.943311  1.745632   8.958151   7.861826  0.013373  0.008948
# 5796    25  2.673203  3.629558  10.170084  13.479431  0.013138  0.011607
.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17720 entries, 0 to 17719
# Columns: 205 entries, 1 to Label
# dtypes: float64(203), int64(2)
# memory usage: 27.7 MB

# %%
CNN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22545 entries, 0 to 22544
# Columns: 201 entries, 1 to Label
# dtypes: float64(199), int64(2)
# memory usage: 34.6 MB

# %%
CNNIBN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33117 entries, 0 to 33116
# Columns: 205 entries, 1 to Label
# dtypes: float64(203), int64(2)
# memory usage: 51.8 MB

# %%
NDTV.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17051 entries, 0 to 17050
# Columns: 205 entries, 1 to Label
# dtypes: float64(203), int64(2)
# memory usage: 26.7 MB

# %%
TIMESNOW.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39252 entries, 0 to 39251
# Columns: 204 entries, 1 to Label
# dtypes: float64(202), int64(2)
# memory usage: 61.1 MB

# %% [markdown]
# Setelah  memiliki statistik deskriptif, kemudian perlu untuk memeriksa nilai yang hilang. Akan dicetak 10 fitur dari data secara berurut dengan lebih dari 10% nilai yang hilang.

# %%
total_BBC = BBC.isnull().sum().sort_values(ascending=False)

percent_BBC = (BBC.isnull().sum()/BBC.isnull().count()) \
.sort_values(ascending=False)

missing_data_BBC = pd.concat([total_BBC, percent_BBC], axis=1, \
                        keys=['Total', 'Missing Percent'])

missing_data_BBC['Missing Percent'] = \
missing_data_BBC['Missing Percent'].apply(lambda x: x*100)

missing_data_BBC.loc[missing_data_BBC['Missing Percent']>= 0][:10]
# Out:
#      Total  Missing Percent
# 441  17702        99.898420
# 141  17691        99.836343
# 882  17643        99.565463
# 212  17635        99.520316
# 621  17613        99.396163
# 223  17531        98.933409
# 478  17516        98.848758
# 229  17431        98.369074
# 462  17316        97.720090
# 178  17261        97.409707

# %%
total_BBC
# Out:
# 441     17702
# 141     17691
# 882     17643
# 212     17635
# 621     17613
#         ...
# 16          0
# 17          0
# 4125        0
# 4124        0
# 1           0
# Length: 205, dtype: int64

# %%
missing_data_BBC
# Out:
#       Total  Missing Percent
# 441   17702        99.898420
# 141   17691        99.836343
# 882   17643        99.565463
# 212   17635        99.520316
# 621   17613        99.396163
# ...     ...              ...
# 16        0         0.000000
# 17        0         0.000000
# 4125      0         0.000000
# 4124      0         0.000000
# 1         0         0.000000
#
# [205 rows x 2 columns]

# %%
total_CNN = CNN.isnull().sum().sort_values(ascending=False)

percent_CNN = (CNN.isnull().sum()/CNN.isnull().count()) \
.sort_values(ascending=False)

missing_data_CNN = pd.concat([total_CNN, percent_CNN], axis=1, \
                        keys=['Total', 'Missing Percent'])

missing_data_CNN['Missing Percent'] = \
missing_data_CNN['Missing Percent'].apply(lambda x: x*100)

missing_data_CNN.loc[missing_data_CNN['Missing Percent']>= 0][:10]
# Out:
#       Total  Missing Percent
# 1028  22221        98.562874
# 882   22196        98.451985
# 621   21962        97.414061
# 230   21934        97.289865
# 240   21902        97.147926
# 220   21845        96.895099
# 215   21768        96.553560
# 231   21757        96.504768
# 519   21740        96.429363
# 463   21714        96.314039

# %%
total_CNN
# Out:
# 1028    22221
# 882     22196
# 621     21962
# 230     21934
# 240     21902
#         ...
# 62          0
# 63          0
# 4125        0
# 4124        0
# 1           0
# Length: 201, dtype: int64

# %%
missing_data_CNN
# Out:
#       Total  Missing Percent
# 1028  22221        98.562874
# 882   22196        98.451985
# 621   21962        97.414061
# 230   21934        97.289865
# 240   21902        97.147926
# ...     ...              ...
# 62        0         0.000000
# 63        0         0.000000
# 4125      0         0.000000
# 4124      0         0.000000
# 1         0         0.000000
#
# [201 rows x 2 columns]

# %%
total_CNNIBN = CNNIBN.isnull().sum().sort_values(ascending=False)

percent_CNNIBN = (CNNIBN.isnull().sum()/CNNIBN.isnull().count()) \
.sort_values(ascending=False)

missing_data_CNNIBN = pd.concat([total_CNNIBN, percent_CNNIBN], axis=1, \
                        keys=['Total', 'Missing Percent'])

missing_data_CNNIBN['Missing Percent'] = \
missing_data_CNNIBN['Missing Percent'].apply(lambda x: x*100)

missing_data_CNNIBN.loc[missing_data_CNNIBN['Missing Percent']>= 0][:10]
# Out:
#       Total  Missing Percent
# 689   33024        99.719177
# 441   32973        99.565178
# 463   32906        99.362865
# 621   32836        99.151493
# 137   32809        99.069964
# 882   32731        98.834435
# 1028  32571        98.351300
# 519   32325        97.608479
# 317   32217        97.282363
# 143   32207        97.252167

# %%
total_CNNIBN
# Out:
# 689     33024
# 441     32973
# 463     32906
# 621     32836
# 137     32809
#         ...
# 63          0
# 64          0
# 4125        0
# 4124        0
# 1           0
# Length: 205, dtype: int64

# %%
missing_data_CNNIBN
# Out:
#       Total  Missing Percent
# 689   33024        99.719177
# 441   32973        99.565178
# 463   32906        99.362865
# 621   32836        99.151493
# 137   32809        99.069964
# ...     ...              ...
# 63        0         0.000000
# 64        0         0.000000
# 4125      0         0.000000
# 4124      0         0.000000
# 1         0         0.000000
#
# [205 rows x 2 columns]

# %%
total_NDTV = NDTV.isnull().sum().sort_values(ascending=False)

percent_NDTV = (NDTV.isnull().sum()/NDTV.isnull().count()) \
.sort_values(ascending=False)

missing_data_NDTV = pd.concat([total_NDTV, percent_NDTV], axis=1, \
                        keys=['Total', 'Missing Percent'])

missing_data_NDTV['Missing Percent'] = \
missing_data_NDTV['Missing Percent'].apply(lambda x: x*100)

missing_data_NDTV.loc[missing_data_NDTV['Missing Percent']>= 0][:10]
# Out:
#      Total  Missing Percent
# 441  16985        99.612926
# 212  16966        99.501496
# 141  16964        99.489766
# 621  16849        98.815319
# 178  16827        98.686294
# 223  16812        98.598323
# 882  16770        98.352003
# 240  16749        98.228843
# 229  16662        97.718609
# 166  16581        97.243563

# %%
total_NDTV
# Out:
# 441     16985
# 212     16966
# 141     16964
# 621     16849
# 178     16827
#         ...
# 61          0
# 62          0
# 4125        0
# 4124        0
# 1           0
# Length: 205, dtype: int64

# %%
missing_data_NDTV
# Out:
#       Total  Missing Percent
# 441   16985        99.612926
# 212   16966        99.501496
# 141   16964        99.489766
# 621   16849        98.815319
# 178   16827        98.686294
# ...     ...              ...
# 61        0         0.000000
# 62        0         0.000000
# 4125      0         0.000000
# 4124      0         0.000000
# 1         0         0.000000
#
# [205 rows x 2 columns]

# %%
total_TIMESNOW = TIMESNOW.isnull().sum().sort_values(ascending=False)

percent_TIMESNOW = (TIMESNOW.isnull().sum()/TIMESNOW.isnull().count()) \
.sort_values(ascending=False)

missing_data_TIMESNOW = pd.concat([total_TIMESNOW, percent_TIMESNOW], axis=1, \
                        keys=['Total', 'Missing Percent'])

missing_data_TIMESNOW['Missing Percent'] = \
missing_data_TIMESNOW['Missing Percent'].apply(lambda x: x*100)

missing_data_TIMESNOW.loc[missing_data_TIMESNOW['Missing Percent']>= 0][:10]
# Out:
#      Total  Missing Percent
# 128  39155        99.752879
# 212  38937        99.197493
# 223  38700        98.593702
# 882  38682        98.547845
# 229  38509        98.107103
# 621  38428        97.900744
# 463  38110        97.090594
# 230  38046        96.927545
# 220  37949        96.680424
# 215  37844        96.412922

# %%
total_TIMESNOW
# Out:
# 128     39155
# 212     38937
# 223     38700
# 882     38682
# 229     38509
#         ...
# 61          0
# 62          0
# 4125        0
# 4124        0
# 1           0
# Length: 204, dtype: int64

# %%
missing_data_TIMESNOW
# Out:
#       Total  Missing Percent
# 128   39155        99.752879
# 212   38937        99.197493
# 223   38700        98.593702
# 882   38682        98.547845
# 229   38509        98.107103
# ...     ...              ...
# 61        0         0.000000
# 62        0         0.000000
# 4125      0         0.000000
# 4124      0         0.000000
# 1         0         0.000000
#
# [204 rows x 2 columns]

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Data Integration

# %%
frames = [BBC, CNN, CNNIBN, NDTV, TIMESNOW] 
merge_dataset = pd.concat(frames).drop_duplicates().reset_index(drop=True)

# %%
merge_dataset.sample(10)
# Out:
#        1         2         3          4          5         6         7     \
# 43509    66  1.630826  1.343415   5.410565   6.051460  0.019469  0.005987
# 26919    90  2.125866  1.086716  17.192394  12.017108  0.007702  0.008417
# 16128    59  0.000000  0.000000   0.000000   0.000000  0.000000  0.000000
# 77030    73  4.505804  3.071002  24.598057  17.286327  0.023238  0.010619
# 88698   124  0.446493  0.673364   4.362092   7.026012  0.011369  0.009411
# 69196    47  1.881671  0.699212   4.404518   1.596320  0.028813  0.011884
# 57996   157  3.742296  2.359779  11.450043   4.185597  0.008580  0.010702
# 33974    46  1.708601  1.420810  11.557614  11.308789  0.017571  0.013343
# 88173    30  1.790936  2.067665   6.147345   8.133594  0.016505  0.007619
# 41221    47  1.029220  0.333833   4.424539   1.408505  0.017353  0.007266
#
#            8         9            10    ...  230   231   269   317   463   \
# 43509  0.089110  0.031567  3717.002441  ...   NaN   NaN   NaN   NaN   NaN
# ...

# %%
nRow, nCol = merge_dataset.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 127457 rows and 215 columns

# %%
merge_dataset.drop_duplicates(keep=False,inplace=True)

# %% [markdown]
# **Seleksi Features dengan menghapus feature yang memiliki nilai null > 25%**

# %%
print(merge_dataset.isnull().sum()/merge_dataset.shape[0])
# Out:
# 1       0.000000
# 2       0.000000
# 3       0.000000
# 4       0.000000
# 5       0.000000
#           ...
# 519     0.976533
# 1028    0.993174
# 137     0.997583
# 689     0.999270
# 128     0.999239
# Length: 215, dtype: float64

# %%
dataset = merge_dataset.loc[:,((merge_dataset.isnull().sum()/merge_dataset.shape[0])*100)<25]

# %%
dataset.shape
# Out:
# (127457, 100)

# %% [markdown]
# **Rename column names**

# %%
MotionDist=[2,3]
FrameDiff=[4,5]
ShortTime=[6,7]
ZCR=[8,9]
SpectralCentroid=[10,11]
SpectralRoll=[12,13]
SpectralFlux=[14,15]
FundamentalFreq=[16,17]
EdgeChange=[4124,4125]
MotionDistbins=[*range(18, 59)]
FrameDiffbins=[*range(59, 92)]
TextAreaDistbins=[*range(92, 123)]
BagAudioWordsbins=[*range(123,4124)] 
l_MotionDist=list()

for m in range(0,len(MotionDistbins)):
    l_MotionDist.append("Motion Distribution bin_"+ str(MotionDistbins[m]))

l_FrameDiff=list()
for f in range(0,len(FrameDiffbins)):
    l_FrameDiff.append("Frame Difference bin_"+ str(FrameDiffbins[f]))
    

l_TextArea=list()
for t in range(0,len(TextAreaDistbins)):
    l_TextArea.append("Text Area Distribution bin_"+ str(TextAreaDistbins[t]))

l_BagAudioWords=list()
for b in range(0,len(BagAudioWordsbins)):
    l_BagAudioWords.append("Bag Audio Words bin_"+ str(BagAudioWordsbins[b]))
    
df_dict={ 1: "Shot Length" ,
        MotionDist[0] : "Motion Distribution Mean",
        MotionDist[1] : "Motion Distribution Variance",
        FrameDiff[0]: 'Frame Difference Distribution Mean',
        FrameDiff[1]: 'Frame Difference Distribution Variance',
        ShortTime[0] : 'Short time energy Mean',
        ShortTime[1] : 'Short time energy Variance',
        ZCR[0] : 'ZCR Mean',
        ZCR[1] : 'ZCR Variance',
        SpectralCentroid[0]:'SpectralCentroid Mean',
        SpectralCentroid[1]:'SpectralCentroid Variance',
        SpectralRoll[0]: 'Spectral Roll off Mean',
        SpectralRoll[1]: 'Spectral Roll off Variance',
        SpectralFlux[0]:'Spectral Flux Mean',
        SpectralFlux[1]:'Spectral Flux Variance',
        FundamentalFreq[0]: 'Fundamental Frequecy Mean',
        FundamentalFreq[1]:'Fundamental Frequecy Variance',
        EdgeChange[0]:'Edge Change Ratio Mean',
        EdgeChange[1]:'Edge Change Ratio Variance',       
}

for i in range(0,len(MotionDistbins)):
    df_dict[MotionDistbins[i]] = l_MotionDist[i]
    
for j in range(0,len(FrameDiffbins)):
    df_dict[FrameDiffbins[j]] = l_FrameDiff[j]
    
for k in range(0,len(TextAreaDistbins)):
    df_dict[TextAreaDistbins[k]] = l_TextArea[k]

for p in range(0,len(BagAudioWordsbins)):
    df_dict[BagAudioWordsbins[p]] = l_BagAudioWords[p]

# %%
namedict = df_dict
cols = dataset.columns
cols = [int(i) for i in cols[:-1]]
colnames = [namedict[i] for i in cols]
colnames.append('Label')

# %%
dataset.columns=colnames

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 127457 entries, 0 to 127456
# Data columns (total 100 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   Shot Length                             127457 non-null  int64
#  1   Motion Distribution Mean                127457 non-null  float64
#  2   Motion Distribution Variance            127457 non-null  float64
#  3   Frame Difference Distribution Mean      127457 non-null  float64
#  4   Frame Difference Distribution Variance  127457 non-null  float64
#  5   Short time energy Mean                  127457 non-null  float64
#  6   Short time energy Variance              127457 non-null  float64
#  7   ZCR Mean                                127457 non-null  float64
#  8   ZCR Variance                            127457 non-null  float64
#  9   SpectralCentroid Mean                   127457 non-null  float64
# ...

# %%
dataset.shape
# Out:
# (127457, 100)

# %%
dataset.sample(10)
# Out:
#         Shot Length  Motion Distribution Mean  Motion Distribution Variance  \
# 126450          211                  1.552318                      1.245325
# 113301           82                  2.921035                      1.053788
# 33744           149                  0.724740                      1.241222
# 80257            29                  1.139318                      0.674182
# 54210           249                  0.712182                      1.548875
# 33154            25                  0.997417                      0.762032
# 86288            35                  6.317136                      3.244512
# 69346           151                  8.988091                      3.726857
# 117167           72                  5.269631                      1.837987
# 40235            43                  2.780919                      1.303787
#
#         Frame Difference Distribution Mean  \
# 126450                            5.617994
# ...

# %% [markdown]
# ###  Data Cleaned

# %%
dataset.isnull().sum()
# Out:
# Shot Length                                   0
# Motion Distribution Mean                      0
# Motion Distribution Variance                  0
# Frame Difference Distribution Mean            0
# Frame Difference Distribution Variance        0
#                                           ...
# Bag Audio Words bin_623                   28934
# Bag Audio Words bin_816                   28572
# Edge Change Ratio Mean                        0
# Edge Change Ratio Variance                    0
# Label                                         0
# Length: 100, dtype: int64

# %%
print(dataset.isnull().values.any())
# Out:
# True

# %%
# menghitung means dan kemudian mengisi nilai null
column_means = dataset.mean()
cleaned_dataset = dataset.fillna(column_means)

# %%
# periksa kembali apakah masih ada data yang missing
print(cleaned_dataset.isnull().values.any())
# Out:
# False

# %%
# cek missing values 
cleaned_dataset.isnull().sum()
# Out:
# Shot Length                               0
# Motion Distribution Mean                  0
# Motion Distribution Variance              0
# Frame Difference Distribution Mean        0
# Frame Difference Distribution Variance    0
#                                          ..
# Bag Audio Words bin_623                   0
# Bag Audio Words bin_816                   0
# Edge Change Ratio Mean                    0
# Edge Change Ratio Variance                0
# Label                                     0
# Length: 100, dtype: int64

# %%
cleaned_dataset.sample(10)
# Out:
#         Shot Length  Motion Distribution Mean  Motion Distribution Variance  \
# 62734           224                  2.965872                      2.198978
# 101496           40                  2.166274                      1.331468
# 24146            32                  1.106560                      0.558330
# 72868            91                  1.464636                      0.910965
# 126521           42                  2.645062                      3.861383
# 106681           50                  3.273112                      2.070890
# 72140            49                  1.602845                      0.758195
# 20086           260                  0.235069                      0.090761
# 98758            58                  7.826329                      2.742866
# 58868           296                  6.004954                      3.313350
#
#         Frame Difference Distribution Mean  \
# 62734                            15.483817
# ...

# %%
# melihat summary dari cleaned_dataset
cleaned_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 127457 entries, 0 to 127456
# Data columns (total 100 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   Shot Length                             127457 non-null  int64
#  1   Motion Distribution Mean                127457 non-null  float64
#  2   Motion Distribution Variance            127457 non-null  float64
#  3   Frame Difference Distribution Mean      127457 non-null  float64
#  4   Frame Difference Distribution Variance  127457 non-null  float64
#  5   Short time energy Mean                  127457 non-null  float64
#  6   Short time energy Variance              127457 non-null  float64
#  7   ZCR Mean                                127457 non-null  float64
#  8   ZCR Variance                            127457 non-null  float64
#  9   SpectralCentroid Mean                   127457 non-null  float64
# ...

# %% [markdown]
# **Features Scalling**

# %%
# Rescale the data
X = cleaned_dataset.drop('Label',axis=1) #Predictors
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))
rescaledX = scaler.fit_transform(X)

# Convert X back to a Pandas DataFrame, for convenience
df = pd.DataFrame(rescaledX, columns=X.columns)

# %%
df['Label'] = cleaned_dataset['Label']

# %%
df
# Out:
#         Shot Length  Motion Distribution Mean  Motion Distribution Variance  \
# 0          0.002895                  0.060724                      0.040575
# 1          0.002925                  0.044562                      0.014625
# 2          0.002482                  0.093887                      0.015300
# 3          0.001802                  0.147884                      0.021045
# 4          0.001507                  0.144648                      0.023990
# ...             ...                       ...                           ...
# 127452     0.000473                  0.025779                      0.006621
# 127453     0.002364                  0.304167                      0.091493
# 127454     0.002216                  0.059955                      0.014546
# 127455     0.001034                  0.026364                      0.013036
# 127456     0.000000                  0.089913                      0.082288
#
#         Frame Difference Distribution Mean  \
# ...

# %%
df.to_csv(r'Dataset DAMI.csv', index=False)

# %%
# Frequency distribution dari values pada variabel
for var in df.columns:
    
    print(df[var].value_counts())
# Out:
# 0.000000    19565
# 0.000030     2912
# 0.000118     2760
# 0.000059     2621
# 0.000207     2612
#             ...
# 0.030964        1
# 0.103675        1
# 0.029339        1
# 0.046002        1
# 0.058618        1
# Name: Shot Length, Length: 1546, dtype: int64
# 0.000000    4014
# 0.054214       8
# 0.062067       8
# 0.193473       8
# 0.109002       8
#             ...
# 0.019065       1
# 0.039990       1
# 0.341326       1
# 0.060618       1
# 0.034535       1
# Name: Motion Distribution Mean, Length: 73237, dtype: int64
# 0.000000    4014
# 0.050421       8
# 0.039094       8
# 0.038240       8
# 0.016934       8
#             ...
# 0.022162       1
# 0.033426       1
# 0.098768       1
# 0.013291       1
# 0.079549       1
# Name: Motion Distribution Variance, Length: 72938, dtype: int64
# 0.000000    4013
# 0.072729       9
# 0.125502       8
# 0.108149       8
# 0.103757       7
#             ...
# 0.169220       1
# 0.372995       1
# 0.076547       1
# 0.038775       1
# ...

# %%
# melihat frequency distribution dari values pada variabel Label 
df['Label'].value_counts()
# Out:
#  1    81222
# -1    46235
# Name: Label, dtype: int64

# %%
# melihat persentasi frequency distribution dari values pada variable Label 
df['Label'].value_counts()/np.float(len(df))
# Out:
#  1    0.63725
# -1    0.36275
# Name: Label, dtype: float64

# %% [markdown]
# Terdapat 2 class label yaitu 1 dan -1, label 1 untuk commercial dan label -1 untuk non-commercial

# %%
# melihat summary statistics
print(round(df.describe(),1))
# Out:
#        Shot Length  Motion Distribution Mean  Motion Distribution Variance  \
# count     127457.0                  127457.0                      127457.0
# mean           0.0                       0.1                           0.0
# std            0.0                       0.1                           0.0
# min            0.0                       0.0                           0.0
# 25%            0.0                       0.0                           0.0
# 50%            0.0                       0.1                           0.0
# 75%            0.0                       0.2                           0.1
# max            1.0                       1.0                           1.0
#
#        Frame Difference Distribution Mean  \
# count                            127457.0
# mean                                  0.2
# std                                   0.1
# min                                   0.0
# 25%                                   0.1
# ...

# %%
# Bar Chart
df['Label'].value_counts().plot(kind='bar', title='TV Channel Commercial Dataset (Cleaned) Label')

# %% [markdown]
# **Correlation**

# %%
correlation = df.corr()

# %%
correlation['Label'].sort_values(ascending=False)
# Out:
# Label                            1.000000
# Spectral Roll off Variance       0.369791
# SpectralCentroid Variance        0.366211
# Bag Audio Words bin_572          0.226921
# Fundamental Frequecy Variance    0.220245
#                                    ...
# Motion Distribution bin_19      -0.182052
# Shot Length                     -0.216074
# Short time energy Variance      -0.234706
# Spectral Flux Variance          -0.277840
# Frame Difference bin_59         -0.324336
# Name: Label, Length: 100, dtype: float64

# %%
corr = df.iloc[:,:20].corr()
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask, k=1)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(15, 11))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap,annot=True,  center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .9})
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
ax.set_title('Correlation matrix of 20 Atributes', fontsize=20)
plt.tight_layout()

# %% [markdown]
# # Modeling

# %%
# Feature vector dan target variable
X = df.drop(['Label'], axis=1)

y = df['Label']

# %%
# Split data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
X_train.shape, X_test.shape
# Out:
# ((101965, 99), (25492, 99))

# %%
#Declare feature vector and target variable
X = df.drop(['Label'], axis=1)

y = df['Label']

# %%
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split 
from sklearn.neighbors import KNeighborsClassifier 
#Check accuracy score
from sklearn.metrics import accuracy_score

#Split data into separate training and test set
# split X and y into training and testing sets

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
# model dengan neighbors = 1
knn_train1 = KNeighborsClassifier(n_neighbors=1)

# fit model dengan training set
knn_train1.fit(X_train, y_train)

# prediksi untuk train-set
y_pred_train1 = knn_train1.predict(X_train)
print('Training-set accuracy score with k=1: {0:0.4f}'. format(accuracy_score(y_train, y_pred_train1)))
# Out:
# Training-set accuracy score with k=1: 1.0000

# %%
# model dengan neighbors = 1
knn1 = KNeighborsClassifier(n_neighbors=1)

# fit model dengan training set
knn1.fit(X_train, y_train)

# prediksi untuk test-set
y_pred1 = knn1.predict(X_test)

print('Test-set accuracy score with k=1 : {0:0.4f}'. format(accuracy_score(y_test, y_pred1)))
# Out:
# Test-set accuracy score with k=1 : 0.8860

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, y_pred1))
print(classification_report(y_test, y_pred1))
# Out:
# [[ 7498  1822]
#  [ 1083 15089]]
#               precision    recall  f1-score   support
#
#           -1       0.87      0.80      0.84      9320
#            1       0.89      0.93      0.91     16172
#
#     accuracy                           0.89     25492
#    macro avg       0.88      0.87      0.87     25492
# weighted avg       0.89      0.89      0.88     25492

# %%
# model dengan neighbors = 3
knn_train3 = KNeighborsClassifier(n_neighbors=3)

# fit model dengan training set
knn_train3.fit(X_train, y_train)

# prediksi untuk train-set
y_pred_train3 = knn_train3.predict(X_train)
print('Training-set accuracy score with k=3: {0:0.4f}'. format(accuracy_score(y_train, y_pred_train3)))
# Out:
# Training-set accuracy score with k=3: 0.9385

# %%
# model dengan neighbors = 3
knn3 = KNeighborsClassifier(n_neighbors=3)

# fit model dengan training set
knn3.fit(X_train, y_train)

# prediksi untuk test-set
y_pred3 = knn3.predict(X_test)

print('Test-set accuracy score with k=3 : {0:0.4f}'. format(accuracy_score(y_test, y_pred3)))
# Out:
# Test-set accuracy score with k=3 : 0.8738

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, y_pred3))
print(classification_report(y_test, y_pred3))
# Out:
# [[ 7213  2107]
#  [ 1110 15062]]
#               precision    recall  f1-score   support
#
#           -1       0.87      0.77      0.82      9320
#            1       0.88      0.93      0.90     16172
#
#     accuracy                           0.87     25492
#    macro avg       0.87      0.85      0.86     25492
# weighted avg       0.87      0.87      0.87     25492
